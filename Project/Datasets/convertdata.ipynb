# %%
import pandas as pd

# %%
data = pd.read_csv('unprepareddata.csv')
prepareddata = pd.DataFrame()
# columns of this dataframe are name , year , value , lastValue
# name is the name of the country
# year is the year of the data
# value is the value of the data
# lastValue is the value of the data of the previous year

for i in range(0, len(data)):
    # for 1990 , lastValue is the current value
    prepareddata = prepareddata.append({'name': data['Name'][i], 'year': '1990', 'value': data['1990'][i], 'lastValue': data['1990'][i]}, ignore_index=True)
    for j in range(1991, 2021):
        prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)

prepareddata.to_csv('racebardata.csv', index=False)
# Out:
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': '1990', 'value': data['1990'][i], 'lastValue': data['1990'][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': '1990', 'value': data['1990'][i], 'lastValue': data['1990'][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': '1990', 'value': data['1990'][i], 'lastValue': data['1990'][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': '1990', 'value': data['1990'][i], 'lastValue': data['1990'][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': '1990', 'value': data['1990'][i], 'lastValue': data['1990'][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# ...
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': '1990', 'value': data['1990'][i], 'lastValue': data['1990'][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
# /var/folders/p6/7ftzfy7d35bcpx9rnxrn15cw0000gn/T/ipykernel_91412/1247981405.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   prepareddata = prepareddata.append({'name': data['Name'][i], 'year': j, 'value': data[str(j)][i], 'lastValue': data[str(j-1)][i]}, ignore_index=True)
